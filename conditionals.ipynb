# %% [markdown]
# <a href="https://colab.research.google.com/github/surekhavydyula4-cmd/Practice/blob/main/conditionals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Even or Odd

# %%
def check_even_odd(num):
  if num%2==0:
    print("Even")
  else:
    print("Odd")
check_even_odd(3)
# Out:
# Odd

# %%
# Positive, Negative, or Zero

# %%
def check(num):
  if num>0:
    print("Positive")
  elif num<0:
    print("Negative")
  else:
    print("Zero")
check(-123)
# Out:
# Negative

# %%
# Largest of Three Numbers

# %%
def check_large_num(num1,num2,num3):
  if num1>=num2 and num1>=num3:
    print(num1)
  elif num2>=num3:
    print(num2)
  else:
    print(num3)
check_large_num(20,13,7)
# Out:
# 20

# %%
# Leap Year

# %%
def check_leap_year(yr):
  if (yr%4==0 and yr%100!=0) or yr%400==0:
    return "Leap year"
  return "Not leap year"
check_leap_year(2016)
# Out:
# 'Leap year'

# %%
# Prime Number

# %%
def check_prime(num):
  if num<=1:
    return "Not prime"
  else:
    for i in range(2,num):
      if num%i==0:
        return "Not prime"
    return "prime"
a=check_prime(23)
a
# Out:
# 'prime'

# %%
# Palindrome Number

# %%
def check_palindrome(num):
  temp=num
  pal_num=0
  while temp>0:
    r=temp%10
    temp=temp//10
    pal_num=(pal_num*10)+r
  if num==pal_num:
    return "Palindrome"
  return "Not palindrome"
check_palindrome(121)
# Out:
# 'Palindrome'

# %%
# Armstrong Number(the sum of its digits raised to the power of the total number of digits is equal to the number itself.)

# %%
def check_arm(num):
  temp=num
  total=0
  n=len(str(num))
  while temp>0:
    r=temp%10
    temp=temp//10
    total+=r**n  # 1**3+5**3+3**3
  if total==num:
    return "Armstrong "
  return "Not armstrong"
check_arm(153)
# Out:
# 'Armstrong '

# %%
# Factorial

# %%
def fact(n):
  temp=1
  if n<=1:
    return 1
  else:
    temp=n*fact(n-1)
  return temp
fact(5)
# Out:
# 120

# %%
# Sum of Digits

# %%
def sum_digits(num):
  total=0
  while num>0:
    r=num%10
    num=num//10
    total+=r
  return total
a=sum_digits(123)
print(a)
# Out:
# 6

# %%
# Simple Calculator

# %%
def cal(a,b,op):
  if op=='+':
    return a+b
  elif op=='-':
    return a-b
  elif op=='*':
    return a*b
  elif op=='/':
    return a/b
  else:
    return a%b
cal(12,34,'+')
# Out:
# 46
